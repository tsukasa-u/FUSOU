# %% [markdown]
# # Fusou Datasets ノートブック入門
# このノートブックでは、Jupyterの基本操作と fusou_datasets を使った最小限の可視化例を日本語で紹介します。

# %% [markdown]
# ## 1. 必要ライブラリのインポート
# numpy / pandas / matplotlib などを読み込み、インポート確認を行います。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fusou_datasets
print("✓ imports ok")

# %% [markdown]
# ## 2. シンプルなコードセル実行
# print や簡単な計算で動作確認をします。

# %%
print("Hello, Fusou!")
print("2 + 3 =", 2 + 3)
print("π ≈", np.pi)

# %% [markdown]
# ## 3. Markdown とコードセルの使い分け
# Markdownで見出し・箇条書き・数式 $e^{i\pi}+1=0$ を書き、コードセルで計算を行います。

# %%
# 箇条書きと数式は上のMarkdownセルを参照
values = [1, 2, 3, 4, 5]
print("平均", np.mean(values))
print("分散", np.var(values))

# %% [markdown]
# ## 4. マジックコマンドとシェルの利用
# %matplotlib inline や %%time、!ls の例を示します。

# %%
# %matplotlib inline
import time
# %%time
_ = sum(range(1_0000))
# !ls -1 .. | head

# %% [markdown]
# ## 5. 保存・エクスポートとメタデータ確認
# nbformatを使ってメタデータを確認し、ファイルとして保存する例です。

# %%
import nbformat
from pathlib import Path

# 現在のノートブックメタデータを確認（サンプルとして空ノード）
nb = nbformat.v4.new_notebook()
print(nb.metadata)

# 保存例（別ファイルとして書き出す）
tmp_path = Path("/tmp/fusou_nb_sample.ipynb")
nbformat.write(nb, tmp_path)
print(f"saved to {tmp_path}")
